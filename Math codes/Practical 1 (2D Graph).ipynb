# %%
from matplotlib.pyplot import*
from numpy import*
x=(10,10,1)
y=x
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=np.arange(-5,5,0.1)
y=x**2+27
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=np.arange(-5,5,0.1)
y=x**4
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(-2*pi,2*pi,0.1)
y=sin(x)
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(-2*pi,2*pi,0.1)
y=cos(x)
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(-pi/4,pi/4,0.1)
y=tan(x)
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(-1,1,0.01)
y=arcsin(x)
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(-1,1,0.01)
y=arccos(x)
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(-1,1,0.01)
y=-x
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(1,10,0.1)
y=log10(x)
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(1,10,0.1)
y=log(x)
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(0,3,0.01)
y=e**x
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(1,5,0.01)
y=e**-x
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(-3,3,0.01)
y=2**x
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(-2*pi,2*pi,0.01)
y=sin(2**x)
plot(x,y)
show()

# %%
from matplotlib.pyplot import*
from numpy import*
x=arange(1,10,0.1)
y=log10(x)
plot(x,y)
show()
